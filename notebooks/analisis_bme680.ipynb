# %%
# Importar librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el archivo CSV
df = pd.read_csv("C:/Users/OmarStrong/Documents/Validation/data/Resultados BME680 - Datos de medición.csv")

# Mostrar las primeras filas
df.head()
# Out:
# Empty DataFrame
# Columns: [N° de prueba, Fecha, Hora, Temperatura sensor (°C), Temperatura patrón (°C), Humedad relativa sensor (%), Humedad  relativa patrón (%), Presión sensor (hPa), Presión patrón (hPa), Diferencia Temperatura (°C), Diferencia Humedad Relativa (%), Diferencia Presion atmosferica (hPa), Observaciones]
# Index: []

# %% [markdown]
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>N° de prueba</th>
#       <th>Fecha</th>
#       <th>Hora</th>
#       <th>Temperatura sensor (°C)</th>
#       <th>Temperatura patrón (°C)</th>
#       <th>Humedad relativa sensor (%)</th>
#       <th>Humedad&nbsp;&nbsp;relativa patrón (%)</th>
#       <th>Presión sensor (hPa)</th>
#       <th>Presión patrón (hPa)</th>
#       <th>Diferencia Temperatura (°C)</th>
#       <th>Diferencia Humedad Relativa (%)</th>
#       <th>Diferencia Presion atmosferica (hPa)</th>
#       <th>Observaciones</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# </div>
